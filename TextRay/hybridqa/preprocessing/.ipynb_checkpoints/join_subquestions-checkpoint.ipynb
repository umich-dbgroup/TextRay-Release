# %%
import pandas as pd
import json
import os
from stringUtils import match_entities
# Out:
# /usr/local/lib/python2.7/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
import sys
print sys.path
# Out:
# ['', '/usr/local/lib/python2.7/dist-packages/kenlm-0.0.0-py2.7-linux-x86_64.egg', '/usr/lib/python2.7', '/usr/lib/python2.7/plat-x86_64-linux-gnu', '/usr/lib/python2.7/lib-tk', '/usr/lib/python2.7/lib-old', '/usr/lib/python2.7/lib-dynload', '/usr/local/lib/python2.7/dist-packages', '/usr/lib/python2.7/dist-packages', '/usr/lib/python2.7/dist-packages/gtk-2.0', '/usr/local/lib/python2.7/dist-packages/IPython/extensions', '/home/xinyi/.ipython']

# %%
INPUT_PREFIX = "../../datasets/ComplexWebQuestions_1_1/Data/"

# %%
import ast
import re
def read_mids_df(path):
    mids = pd.read_csv(path, encoding='utf-8')
    mids['names'] = mids['names'].fillna('[]')
    mids['names'] = mids['names'].apply(lambda x: str(x).replace('][', ','))
    mids['names'] = mids['names'].apply(ast.literal_eval)
    return mids

# %%
from stringUtils import fuzzy_match_entities
from stringUtils import sim_match_entities
def process_split_part1(row, mid_df):
    mid_df_sub = mid_df[mid_df['ID'] == row.ID]
    mid_df_sub = mid_df_sub.drop_duplicates('mid')
    new_split_part = row.split_part1.copy()
    sub_ques = new_split_part[u"sub_ques"]
    mid_df_sub = mid_df[mid_df['ID'] == row.ID]
    mid_df_sub = mid_df_sub.drop_duplicates('mid')
    matched = []
    for idx, mid_row in mid_df_sub.iterrows():
        mid = mid_row.mid
        if mid is None:
            continue
        names = mid_row.names
        found = 0
        for name in names:
            m = re.search(re.escape(name), sub_ques, re.IGNORECASE)
            if m:
                matched.append({"mid": mid, "mention": name})
                found = 1
                break
        if found == 0:
            matched_seq, score = sim_match_entities(sub_ques, names)
            if matched_seq:
                print "Question: " + row.question
                print "Matched Sequence: " + matched_seq"
                print "Score: " + str(score)
                print '\n'
                matched.append({"mid":mid, "mention": matched_seq})
    return {"sub_ID":new_split_part["sub_ID"], "sub_ques": sub_ques, "entities": matched}

def process_split_part2(row, mid_df):
    mid_df_sub = mid_df[mid_df['ID'] == row.ID]
    mid_df_sub = mid_df_sub.drop_duplicates('mid')
    new_split_part = row.split_part2.copy()
    sub_ques = new_split_part[u"sub_ques"]
    mid_df_sub = mid_df[mid_df['ID'] == row.ID]
    mid_df_sub = mid_df_sub.drop_duplicates('mid')
    matched = []
    for idx, mid_row in mid_df_sub.iterrows():
        mid = mid_row.mid
        if mid is None:
            continue
        names = mid_row.names
        found = 0
        for name in names:
            m = re.search(re.escape(name), sub_ques, re.IGNORECASE)
            if m:
                matched.append({"mid": mid, "mention": name})
                found = 1
                break
        if found == 0:
            matched_seq, score = sim_match_entities(sub_ques, names)
            if matched_seq:
                print "Question: " + row.question
                print "Matched Sequence: " + matched_seq"
                print "Score: " + str(score)
                print '\n'
                matched.append({"mid":mid, "mention": matched_seq})
    return {"sub_ID":new_split_part["sub_ID"], "sub_ques": sub_ques, "entities": matched}

# %%
choices = ['dev','test','train']
for choice in choices:
    print "start " + choice
    file_path = os.path.join(INPUT_PREFIX, "annotated_complex_web_questions_bk/" + choice + ".json")
    data = json.load(open(file_path))
    questions = pd.DataFrame(data)
    mid_df = read_mids_df(os.path.join(INPUT_PREFIX, 'qid_mid_names/' + choice + '_mid_names.tsv'))
    questions["new_split_part1"] = questions.apply(process_split_part1, args=(mid_df,), axis=1)
    questions["new_split_part2"] = questions.apply(process_split_part2, args=(mid_df,), axis=1)
    questions["split_part1"] = questions["new_split_part1"]
    questions["split_part2"] = questions["new_split_part2"]
    questions = questions.drop(['new_split_part1', 'new_split_part2'], axis=1)
    with open(os.path.join(INPUT_PREFIX, 'annotated_complex_web_questions/' + choice + ".json"), 'w+') as output_file:
        json.dump(questions.to_dict(orient='records'), output_file, indent=4)
# Out:
# start dev
# nicholas s zeppos 0.482142857143
# Question: What is the mascot of the team that has Nicholas S. Zeppos as its leader?
# Matched Sequence: nicholas s zeppos Score: 0.482142857143
#
#
# skovakia 0.5
# Question: Which country that borders Skovakia is Kiev the capital of?
# Matched Sequence: skovakia Score: 0.5
#
#
# 1906 intercalted games 0.406976744186
# Question: Which city hosted the 1906 Intercalted games and was knows for having Greek Temples?
# Matched Sequence: 1906 intercalted games Score: 0.406976744186
#
#
# university of south carolina beaufort 0.521739130435
# Question: From where is the University of South Carolina Beaufort Child Organization?
# Matched Sequence: university of south carolina beaufort Score: 0.521739130435
#
#
# du gamla , du fria 0.45
# Question: What kind of money does the country with the nation antem Du gamla, Du fria use?
# Matched Sequence: du gamla , du fria Score: 0.45
#
#
# balochistan 0.5
# Question: The country that contains Balochistan, Pakistan had what President in 1980?
# Matched Sequence: balochistan Score: 0.5
#
#
# sacatepaquez department 0.506172839506
# Question: The SacatepÃ©quez Department is which of 3 countries bordering Mexico?
# Matched Sequence: sacatepaquez department Score: 0.506172839506
#
#
# evelynn m hammonds 0.5
# Question: In which state is the organization that has Evelynn M. Hammonds among its leaders located?
# Matched Sequence: evelynn m hammonds Score: 0.5
#
#
# pakistani repuu 0.444444444444
# Question: Who was the president in 1980 of the nation that uses the Pakistani repuu as money?
# Matched Sequence: pakistani repuu Score: 0.444444444444
#
#
# hamilton g ewart 0.444444444444
# Question: Where is the location of the school where Hamilton G. Ewart is a grad student?
# Matched Sequence: hamilton g ewart Score: 0.444444444444
#
#
# imperial national anthems of the ottoman 0.518248175182
# Question: Where is the country with Imperial national Anthems of the Ottoman Empire located?
# Matched Sequence: imperial national anthems of the ottoman Score: 0.518248175182
#
#
# northern division 0.44
# Question: What type of government does Northern Division, Fiji have?
# Matched Sequence: northern division Score: 0.44
#
#
# central division 0.416666666667
# Question: What form of government does the country that has Central Division, Fiji have?
# Matched Sequence: central division Score: 0.416666666667
#
#
# noble patria , tu hermosa 0.58
# Question: What is the currency used in the country with the national anthem Noble Patria, Tu Hermosa Bandera?
# Matched Sequence: noble patria , tu hermosa Score: 0.58
#
#
# cherifian 0.409090909091
# Question: What is the capital of the country with the Cherifian National Anthem?
# Matched Sequence: cherifian Score: 0.409090909091
#
#
# greek temples 0.45
# Question: Where were Greek Temples built in the Eastern European Time Zone?
# Matched Sequence: greek temples Score: 0.45
#
#
# ibrahim boubacar is 0.423076923077
# Question: What is the type of government where Ibrahim Boubacar is in a government position?
# Matched Sequence: ibrahim boubacar is Score: 0.423076923077
#
#
# noble patria , tu hermosa bandera 0.8
# Question: Which continent is in the country, that has the national anthem, Noble patria, tu hermosa bandera located at?
# Matched Sequence: noble patria , tu hermosa bandera Score: 0.8
#
#
# mediterranian 0.488372093023
# Question: What country is a part of the mediterranian region and is a part of the Western European Time zone?
# Matched Sequence: mediterranian Score: 0.488372093023
#
#
# khentil 0.428571428571
# Question: What type of government is used in the country with Khentil Province?
# Matched Sequence: khentil Score: 0.428571428571
#
#
# colorado eagles professional 0.427480916031
# Question: What kind of team is the sports team whose owner is Colorado Eagles Professional Hockey LLC?
# Matched Sequence: colorado eagles professional Score: 0.427480916031
#
#
# language 0.428571428571
# Question: When I visit the country where Nama is a spoken language, what kind of money should I take with me?
# Matched Sequence: language Score: 0.428571428571
#
#
# trafford , greater manchester 0.434782608696
# Question: Which team from Old Trafford, Greater Manchester has won the most FA cups?
# Matched Sequence: trafford , greater manchester Score: 0.434782608696
#
#
# seriously , i do not think i fit for the presidency 0.684848484848
# Question: What inauguration did the person that said "Seriously, I do not think I fit for the presidency." participate in?
# Matched Sequence: seriously , i do not think i fit for the presidency Score: 0.684848484848
#
#
# jonas brother 0.4375
# Question: What Jonas Brother played the character Shane Gray?
# Matched Sequence: jonas brother Score: 0.4375
#
#
# 2010 united states senate election , in florida 0.482558139535
# Question: Where should I go in the state that held the 2010 United States Senate election, in Florida, for vacation?
# Matched Sequence: 2010 united states senate election , in florida Score: 0.482558139535
#
#
# rhianna 0.428571428571
# Question: Which film starring Rhianna involved the National Film Board of Canada?
# Matched Sequence: rhianna Score: 0.428571428571
#
#
# state of the union addresses of william j 0.455089820359
# Question: Which high school did the President who wrote the State of the Union Addresses of William J. Clinton attend?
# Matched Sequence: state of the union addresses of william j Score: 0.455089820359
#
#
# 'm with you 0.5
# Question: Who does the artist nominated for "I'm With You" play in "Over the Hedge"?
# Matched Sequence: 'm with you Score: 0.5
#
#
# forgive your enemies , but never forget their names 0.856164383562
# Question: With whom did the person who said "Forgive your enemies, but never forget their names" have affairs?
# Matched Sequence: forgive your enemies , but never forget their names Score: 0.856164383562
#
#
# jamtlands bryggeri hell 0.448275862069
# Question: What type of money is used int he country of origin for  JÃ¤mtlands Bryggeri Hell beer?
# Matched Sequence: jamtlands bryggeri hell Score: 0.448275862069
#
#
# a good picture is equivalent to a good deed 0.947368421053
# Question: What art movement does the person that said "A good picture is equivalent to a good deed." belong to?
# Matched Sequence: a good picture is equivalent to a good deed Score: 0.947368421053
#
#
# the most positive men are the most credulous 0.942857142857
# Question: What was the occuipation of the person who quoted "The most positive men are the most credulous."?
# Matched Sequence: the most positive men are the most credulous Score: 0.942857142857
#
#
# the welfare of each is bound up in the welfare of all 0.949152542373
# Question: What school did the person that said "The welfare of each is bound up in the welfare of all." attend?
# Matched Sequence: the welfare of each is bound up in the welfare of all Score: 0.949152542373
#
#
# rhianna 0.428571428571
# Question: Which award nominated film starring Rhianna was described as "Based on the boardgame by Hasbro?"?
# Matched Sequence: rhianna Score: 0.428571428571
#
#
# junction of highways 0.593023255814
# Question: Who is the subject of the image "junction of highways 46 and 41?"?
# Matched Sequence: junction of highways Score: 0.593023255814
#
#
# tarzan and jane regained sort of 0.425196850394
# Question: What artists were influencers of the actor who starred in the movie Tarzan and Jane Regained... Sort of 's work?
# Matched Sequence: tarzan and jane regained sort of Score: 0.425196850394
#
#
# good gi bill would increase the recruit pool 0.780141843972
# Question: What was the birth place of the person that said "a good GI bill would increase the recruit pool"?
# Matched Sequence: good gi bill would increase the recruit pool Score: 0.780141843972
#
#
# forgive your enemies , but never forget their names 0.856164383562
# Question: What city was the President who said "Forgive your enemies, but never forget their names." killed in?
# Matched Sequence: forgive your enemies , but never forget their names Score: 0.856164383562
#
#
# nicephore 0.428571428571
# Question: Nicephore Niecpe created what style of art that was later used by Salvador Dali?
# Matched Sequence: nicephore Score: 0.428571428571
#
#
# zamenhof 0.416666666667
# Question: What language was invented by L. L. Zamenhof and is used in Japan?
# Matched Sequence: zamenhof Score: 0.416666666667
#
#
# hatred is gained as much by good works as by evil 0.9296875
# Question: In what city did the person who stated "Hatred is gained as much by good works as by evil."  reside?
# Matched Sequence: hatred is gained as much by good works as by evil Score: 0.9296875
#
#
# jonas brother 0.4375
# Question: Which Jonas brother was nominated for a Teen Choice Award for TV Male Reality Star?
# Matched Sequence: jonas brother Score: 0.4375
#
#
# under secretary of defense for personnel 0.455555555556
# Question: What country is the current Under Secretary of Defense for Personnel and Readines originally from?
# Matched Sequence: under secretary of defense for personnel Score: 0.455555555556
#
#
# florida gubernatorial election 0.764705882353
# Question: When I take my family to the state that held the 2010 Florida gubernatorial election on vacation, where all should we go?
# Matched Sequence: florida gubernatorial election Score: 0.764705882353
#
#
# mapudungan 0.5
# Question: What is the spoken languages in the country where Mapudungan language is used?
# Matched Sequence: mapudungan Score: 0.5
# nothing pains some people more than having to think 0.931818181818
# Question: Who's the person that said, "Nothing pains some people more than having to think." ?
# Matched Sequence: nothing pains some people more than having to think Score: 0.931818181818
#
#
# nothing pains some people more than having to think 0.931818181818
# Question: From which university did the person who said Nothing pains some people more than having to think." receive his doctorate?
# Matched Sequence: nothing pains some people more than having to think Score: 0.931818181818
#
#
# united states senate special election in missouri 0.583333333333
# Question: What's the legislature of the state that held the United States Senate special election in Missouri, in 2002 called?
# Matched Sequence: united states senate special election in missouri Score: 0.583333333333
#
#
# the most dangerous moment comes with victory 0.934959349593
# Question: Where is the burial place of the person who said "The most dangerous moment comes with victory."?
# Matched Sequence: the most dangerous moment comes with victory Score: 0.934959349593
#
#
# santiago bernabau stadium 0.422680412371
# Question: What sports team that plays its home games at Santiago BernabÃ©u Stadium has Cristiano Ronaldo on its roster?
# Matched Sequence: santiago bernabau stadium Score: 0.422680412371
#
#
# mcclarnon in concert poland 0.428571428571
# Question: Where does the main performer of "Liz McClarnon in concert Poland (2005)" live?
# Matched Sequence: mcclarnon in concert poland Score: 0.428571428571
#
#
# invention is the talent of youth , as judgement of age 0.71974522293
# Question: What made the person who said "Invention is the talent of youth, as judgement of age." famous?
# Matched Sequence: invention is the talent of youth , as judgement of age Score: 0.71974522293
#
#
# good gi bill would increase the recruit pool 0.780141843972
# Question: What country is the birthplace of the person who said, "A good GI bill would increase the recruit pool"?
# Matched Sequence: good gi bill would increase the recruit pool Score: 0.780141843972
#
#
# he speaks to me as if i was a public meeting 0.707142857143
# Question: What countries does the person who said "He speaks to Me as if I was a public meeting" rule?
# Matched Sequence: he speaks to me as if i was a public meeting Score: 0.707142857143
#
#
# friedrich halderlin 0.538461538462
# Question: Which peer of Friedrich HÃ¶lderlin inspired the work of Walt Whitman?
# Matched Sequence: friedrich halderlin Score: 0.538461538462
#
#
# the best way to know god is to love many things 0.812949640288
# Question: What art movement practiced by the person that said "The best way to know God is to love many things."?
# Matched Sequence: the best way to know god is to love many things Score: 0.812949640288
#
#
# that was then , this is 0.605263157895
# Question: What University did the author who published editions for, That was then, this is now, attend?
# Matched Sequence: that was then , this is Score: 0.605263157895
#
#
# israeli sheckel 0.440677966102
# Question: On which continent is the Old Israeli sheckel accepted as currency?
# Matched Sequence: israeli sheckel Score: 0.440677966102
#
#
# quechuan languags 0.711538461538
# Question: What nations border the country where the Quechuan languags are used?
# Matched Sequence: quechuan languags Score: 0.711538461538
#
#
# henceforth i ask not good fortune i myself am good fortune 0.697986577181
# Question: Who influence the poetry of the person who said "Henceforth I ask not good fortune. I myself am good fortune."?
# Matched Sequence: henceforth i ask not good fortune i myself am good fortune Score: 0.697986577181
#
#
# cerveza nacional 0.430555555556
# Question: Which countries border ,where the Cerveza Nacional PaceÃ±a beer is manufactured?
# Matched Sequence: cerveza nacional Score: 0.430555555556
#
#
# chris-paul 0.666666666667
# Question: What team does the person in the image chris-paul. jpg play on?
# Matched Sequence: chris-paul Score: 0.666666666667
#
#
# college is n't the place to go for ideas 0.801652892562
# Question: Where did the person that stated, "College isn't the place to go for ideas.", attend school?
# Matched Sequence: college is n't the place to go for ideas Score: 0.801652892562
#
#
# recognition of the japanese 0.508064516129
# Question: In what state did the actor who played in the film "Recognition of the Japanese Zero Fighter" the governor?
# Matched Sequence: recognition of the japanese Score: 0.508064516129
#
#
# aglaulus , daughter of cecrops 0.613861386139
# Question: Where was the ficitional character Aglaulus, daughter of Cecrops born and the Greek temples built?
# Matched Sequence: aglaulus , daughter of cecrops Score: 0.613861386139
#
#
# state of the union addresses of william j 0.455089820359
# Question: Where did the author who published the State of the Union Addresses of William J. Clinton attend college?
# Matched Sequence: state of the union addresses of william j Score: 0.455089820359
#
#
# suspense is worst than disappointment 0.916666666667
# Question: Which occupation, was the person that stated, "Suspense is worst than disappointment.", famous for?
# Matched Sequence: suspense is worst than disappointment Score: 0.916666666667
#
#
# 2002-03 0.416666666667
# Question: In what series that occurred a year before the 2002-03 FA Cup did Arsenal emerge victorious?
# Matched Sequence: 2002-03 Score: 0.416666666667
#
#
# united states senate election in kentucky 0.515923566879
# Question: What is the slogan of the state held the United States Senate Election in Kentucky in 2010?
# Matched Sequence: united states senate election in kentucky Score: 0.515923566879
#
#
# director of multilateral affairs 0.495798319328
# Question: Which Director of Multilateral Affairs from 2012 has run for Vice President?
# Matched Sequence: director of multilateral affairs Score: 0.495798319328
#
#
# greek temple 0.473684210526
# Question: In what location of a greek temple did the fictional character Herakleitos of Ephesos live?
# Matched Sequence: greek temple Score: 0.473684210526
#
#
# greek temples 0.45
# Question: At what place where Greek temples built, and is home to the fictional character Heraclitus?
# Matched Sequence: greek temples Score: 0.45
#
#
# ability is of little account without opportunity 0.932330827068
# Question: Where is the grave site of the person who said, "ability is of little account without opportunity"?
# Matched Sequence: ability is of little account without opportunity Score: 0.932330827068
#
#
# pink is n't just a color , it 's an attitude 0.636363636364
# Question: What was the movie in which someone said "Pink isn't just a color, it's an attitude?"?
# Matched Sequence: pink is n't just a color , it 's an attitude Score: 0.636363636364
#
#
# have no fear of perfection - you 'll never reach it 0.843137254902
# Question: What artistic genre is associated with this line's author: "Have no fear of perfection - you'll never reach it."?
# Matched Sequence: have no fear of perfection - you 'll never reach it Score: 0.843137254902
#
#
# double-nosed-andean tiger 0.545454545455
# Question: What countries border the country of origin for the Double-nosed-Andean tiger hound?
# Matched Sequence: double-nosed-andean tiger Score: 0.545454545455
#
#
# greelandic language 0.65
# Question: Where is the location of the country where the Greelandic language is spoken?
# Matched Sequence: greelandic language Score: 0.65
#
#
# the future 0.489795918367
# Question: To what country does the North to the future belong as an official symbol?
# Matched Sequence: the future Score: 0.489795918367
#
#
# have no fear of perfection-you 'll never reach it 0.836734693878
# Question: What artistic genre is associated with this line's author: "Have no fear of perfection-you'll never reach it."?
# Matched Sequence: have no fear of perfection-you 'll never reach it Score: 0.836734693878
#
#
# painted with words 0.404494382022
# Question: what art movement does Vincent Van Gogh ,the subject of the film Painted with Words ,belong to?
# Matched Sequence: painted with words Score: 0.404494382022
#
#
# into the arms of strangers : stories of the kindertransport 0.536312849162
# Question: What currency is currently used in the setting of the movie  "Into the Arms of Strangers: Stories of the Kindertransport?"?
# Matched Sequence: into the arms of strangers : stories of the kindertransport Score: 0.536312849162
#
#
# german 0.5
# Question: What city is the place where a German citizen was born in and where Joey King lives in.?
# Matched Sequence: german Score: 0.5
# yes we can 0.7
# Question: What city is the birthplace of the person who said "Yes we can!"?
# Matched Sequence: yes we can Score: 0.7
#
#
# theme song of general hospital tv 0.542857142857
# Question: Who is playing Jason Morgan on the theme song of General Hospital tv program?
# Matched Sequence: theme song of general hospital tv Score: 0.542857142857
#
#
# computer geek # 0.5
# Question: The actor that played the Computer Geek #1 also played for what teams?
# Matched Sequence: computer geek # Score: 0.5
#
#
# mozambique 0.4375
# Question: The river that flows through Songo, Mozambique originates where?
# Matched Sequence: mozambique Score: 0.4375
#
#
# am a deeply superficial person 0.910112359551
# Question: Find the person who said "I am a deeply superficial person", who influenced their work?
# Matched Sequence: am a deeply superficial person Score: 0.910112359551
#
#
# griffin 0.5
# Question: What character that is the father of Chris Griffin does Seth MacFarlane voice?
# Matched Sequence: griffin Score: 0.5
#
#
# boston society of film critics awards 0.417721518987
# Question: Who was an award nominee in the Boston Society of Film Critics Awards and got married in 2003?
# Matched Sequence: boston society of film critics awards Score: 0.417721518987
#
#
# taste can not be controlled by law 0.769230769231
# Question: Find the person who said "Taste cannot be controlled by law", what did this person die from?
# Matched Sequence: taste can not be controlled by law Score: 0.769230769231
#
#
# traveling makes a man wiser , but less happy 0.81954887218
# Question: What is the place of death for the person who said "Traveling makes a man wiser, but less happy?"?
# Matched Sequence: traveling makes a man wiser , but less happy Score: 0.81954887218
#
#
# 1993-94 0.416666666667
# Question: What year prior to the 1993-94 FA Cup did Arsenal win the league?
# Matched Sequence: 1993-94 Score: 0.416666666667
#
#
# i dreamed i lay where flowers were springing 0.618705035971
# Question: What made the person who wrote the lyrics for "I Dreamed I Lay Where Flowers Were Springing" famous?
# Matched Sequence: i dreamed i lay where flowers were springing Score: 0.618705035971
#
#
# without alienation , there can be no politics 0.82962962963
# Question: The person who said "Without alienation, there can be no politics" was influenced by who?
# Matched Sequence: without alienation , there can be no politics Score: 0.82962962963
#
#
# lord of the rings : the fellowship of the ring 0.458646616541
# Question: Who plays Saruman in The Lord of the Rings: The Fellowship of the Ring, a film with a soundtrack?
# Matched Sequence: lord of the rings : the fellowship of the ring Score: 0.458646616541
#
#
# jonas brother 0.4375
# Question: Which Jonas Brother most recently ended a relationship?
# Matched Sequence: jonas brother Score: 0.4375
#
#
# greek temples 0.45
# Question: What city features both Greek temples and a neighborhood called Ano Patissia?
# Matched Sequence: greek temples Score: 0.45
#
#
# breakfast at 0.44262295082
# Question: What type of cancer caused the death of an actor in Breakfast at Tiffany's?
# Matched Sequence: breakfast at Score: 0.44262295082
#
#
# languages 0.409090909091
# Question: What family of Aragonese Languages did English language evolved from?
# Matched Sequence: languages Score: 0.409090909091
#
#
# computer geek # 0.5
# Question: In what year was the actor who portrayed Computer Geek #1 drafted?
# Matched Sequence: computer geek # Score: 0.5
#
#
# american football 0.423076923077
# Question: What American Football player was the first leader of the AFL?
# Matched Sequence: american football Score: 0.423076923077
#
#
# argentino 0.461538461538
# Question: What countries border the country of origin for the Dog Argentino breed/?
# Matched Sequence: argentino Score: 0.461538461538
#
#
# united states senate election for hawaii in 0.417647058824
# Question: The United States Senate election for Hawaii in 2010 was held in which time zone?
# Matched Sequence: united states senate election for hawaii in Score: 0.417647058824
#
#
# associate justice of the supreme court of 0.462857142857
# Question: What is the judge in the court where title Associate justice of the Supreme Court of US serve called?
# Matched Sequence: associate justice of the supreme court of Score: 0.462857142857
#
#
# purepecha langiage 0.43661971831
# Question: WHat three countries border the nation where the Purepecha langiage is spoken?
# Matched Sequence: purepecha langiage Score: 0.43661971831
#
#
# the story of glittering plain 0.456896551724
# Question: Who wrote the Story of Glittering Plain that inspired Antoni Gaudi?
# Matched Sequence: the story of glittering plain Score: 0.456896551724
#
#
# who is rich he that rejoices in his portion 0.742647058824
# Question: Who is rich? He that rejoices in his portion, was said by a person with what job?
# Matched Sequence: who is rich he that rejoices in his portion Score: 0.742647058824
#
#
# 2008 united states senate election in tennessee 0.536144578313
# Question: A state held the 2008 United States Senate Election in Tennessee; what is its governor?
# Matched Sequence: 2008 united states senate election in tennessee Score: 0.536144578313
#
#
# government 0.466666666667
# Question: What European Union country's government is called the government of Ireland?
# Matched Sequence: government Score: 0.466666666667
#
#
# accept reality and dare not question it 0.931034482759
# Question: Who influenced the poetry of the person who said, "I accept reality and dare not question it"?
# Matched Sequence: accept reality and dare not question it Score: 0.931034482759
#
#
# a fossil 0.454545454545
# Question: Which state has the official state symbol of a Fossil and has Littleton in downtown?
# Matched Sequence: a fossil Score: 0.454545454545
#
#
# jonas brother 0.4375
# Question: Which Jonas brother was featured in Johnny Kapahala" Back on Board?
# Matched Sequence: jonas brother Score: 0.4375
#
#
# tropical depression 0.481481481481
# Question: What area was affected by Cyclone Tropical Depression 2-E?
# Matched Sequence: tropical depression Score: 0.481481481481
#
#
# not simultaneously prevent and prepare for war 0.847222222222
# Question: What jobs were held by the person who said, "You cannot simultaneously prevent and prepare for war"?
# Matched Sequence: not simultaneously prevent and prepare for war Score: 0.847222222222
#
#
# power plugs 0.411764705882
# Question: What country uses power plugs type c and speaks Arabic?
# Matched Sequence: power plugs Score: 0.411764705882
#
#
# attorney for the northern district of georgia 0.550898203593
# Question: The political appointee who's currently the U.S. Attorney for the Northern District of Georgia is the former Governor of what state?
# Matched Sequence: attorney for the northern district of georgia Score: 0.550898203593
#
#
# zamenhof 0.416666666667
# Question: What language invented by L.L Zamenhof is spoken in Austrailia?
# Matched Sequence: zamenhof Score: 0.416666666667
#
#
# stephe regelous 0.421052631579
# Question: Stephe Regelous was a crew member on a movie with a character called Saruman, who played Saurman?
# Matched Sequence: stephe regelous Score: 0.421052631579
#
#
# yes we can 0.7
# Question: What country is the person that said "Yes we can!" from?
# Matched Sequence: yes we can Score: 0.7
#
#
# gentlemen of verona 0.441860465116
# Question: Who is the author who wrote Two Gentlemen of Verona and influenced Arthur Miller?
# Matched Sequence: gentlemen of verona Score: 0.441860465116
#
#
# bill clinton : speeches of the presidential years 0.420560747664
# Question: What college did the actor that starred in the film Bill Clinton: Speeches of the Presidential Years, 1993-2001 attend?
# Matched Sequence: bill clinton : speeches of the presidential years Score: 0.420560747664
#
#
# engineering language 0.530303030303
# Question: Which "engineering language" conlang is spoken by people in Argentina?
# Matched Sequence: engineering language Score: 0.530303030303
#
#
# television 0.5
# Question: What television movie starred Lucy Hale?
# Matched Sequence: television Score: 0.5
#
#
# corso on the set college 0.504672897196
# Question: What college did the topic of the image Corso on the set College Game Day attend?
# Matched Sequence: corso on the set college Score: 0.504672897196
#
#
# the office of associate director , white house office of public liaison 0.64824120603
# Question: In what city was the person holding the office of Associate Director , White House Office of Public Liaison born?
# Matched Sequence: the office of associate director , white house office of public liaison Score: 0.64824120603
#
#
# attorney for the northern district of 0.493670886076
# Question: Who shot the politician who had been the U.S. Attorney for the Northern District of Georgia?
# Matched Sequence: attorney for the northern district of Score: 0.493670886076
#
#
# jonas brother 0.4375
# Question: Which Jonas brother had a romantic relationship that ended in October of 2008?
# Matched Sequence: jonas brother Score: 0.4375
# origin of species -lrb- enriched classics 0.413580246914
# Question: What books were published by the author of the Origin of Species (Enriched Classics)?
# Matched Sequence: origin of species -lrb- enriched classics Score: 0.413580246914
#
#
# gregor the overlander -lrb- underland chronicles -lrb- sagebrush 0.455445544554
# Question: What children's books were written by the authoer of  Gregor the Overlander (Underland Chronicles (Sagebrush)?
# Matched Sequence: gregor the overlander -lrb- underland chronicles -lrb- sagebrush Score: 0.455445544554
#
#
# george washington 0.428571428571
# Question: What college did George Washington attend that publishes the newspaper Iowa State Daily?
# Matched Sequence: george washington Score: 0.428571428571
#
#
# robert darcy , 4th earl of holderness 0.460431654676
# Question: In what birthplace of Robert Darcy, 4th Earl of Holderness do people speak Welsh?
# Matched Sequence: robert darcy , 4th earl of holderness Score: 0.460431654676
#
#
# thomas jefferson 's 1801 presidential 0.519230769231
# Question: In what location did the speaker at Thomas Jefferson's 1801 Presidential inauguration die?
# Matched Sequence: thomas jefferson 's 1801 presidential Score: 0.519230769231
#
#
# i destroy my enemy when i make him my friend 0.801587301587
# Question: On what date was the person inaugerated who said "I destroy my enemy when I make him my friend."?
# Matched Sequence: i destroy my enemy when i make him my friend Score: 0.801587301587
#
#
# greek temples 0.45
# Question: What location of Greek temples has a population of 43376?
# Matched Sequence: greek temples Score: 0.45
#
#
# language 0.439024390244
# Question: Which Church Slavonic language has the English language evolved from?
# Matched Sequence: language Score: 0.439024390244
#
#
# money does n't talk , it swears 0.625
# Question: What is the home city of the person who said "Money doesn't talk, it swears"?
# Matched Sequence: money does n't talk , it swears Score: 0.625
#
#
# wimbledon 2007 final : federer vs 0.459259259259
# Question: What City is home to the actor featured in the movie Wimbledon 2007 Final: Federer vs. Nadal from sui?
# Matched Sequence: wimbledon 2007 final : federer vs Score: 0.459259259259
#
#
# march on washington for jobs 0.409090909091
# Question: Who was the speaker at March on Washington for Jobs and Freedom facts?
# Matched Sequence: march on washington for jobs Score: 0.409090909091
#
#
# episcopalian church 0.415384615385
# Question: Which member of the episcopalian church was married to liz taylor?
# Matched Sequence: episcopalian church Score: 0.415384615385
#
#
# social demokraten 0.5
# Question: Find the country that ciruclates a newspaper called Social Demokraten, what is the name of the currency in that area?
# Matched Sequence: social demokraten Score: 0.5
#
#
# sanjak of 0.428571428571
# Question: Where is the country that has Sanjak of ÃskÃ¼p located?
# Matched Sequence: sanjak of Score: 0.428571428571
#
#
# william o schaefer elementary 0.428571428571
# Question: Who is the brother of the famous person who went to William O. Schaefer Elementary School?
# Matched Sequence: william o schaefer elementary Score: 0.428571428571
#
#
# harry potters series 0.450704225352
# Question: Which Harry Potters series films in chronological order were directed by Lucinda Thompson?
# Matched Sequence: harry potters series Score: 0.450704225352
#
#
# dapaache tunisienne 0.5
# Question: What currency is used in the country where the La DÃ©pÃªche tunisienne is circulated?
# Matched Sequence: dapaache tunisienne Score: 0.5
#
#
# rihanna performing at kanye west 's glow in the dark 0.473684210526
# Question: What movie did the subject of the image "Rihanna performing at Kanye West's Glow in the Dark Tour" play in?
# Matched Sequence: rihanna performing at kanye west 's glow in the dark Score: 0.473684210526
#
#
# carolina kennedy 0.406779661017
# Question: Of the schools that Carolina Kennedy attended, which one has the earliest founding date?
# Matched Sequence: carolina kennedy Score: 0.406779661017
#
#
# wealth of nation 0.434782608696
# Question: Name the place of birth of the author who published The Wealth of Nation editions .?
# Matched Sequence: wealth of nation Score: 0.434782608696
#
#
# let us do or die 0.808510638298
# Question: What was the person that stated, "Let us do or die." famous for?
# Matched Sequence: let us do or die Score: 0.808510638298
#
#
# government does not solve problems ; it subsidizes them 0.857142857143
# Question: What state was the person the governor for that said "government does not solve problems; it subsidizes them"?
# Matched Sequence: government does not solve problems ; it subsidizes them Score: 0.857142857143
#
#
# eastern berber language 0.662162162162
# Question: What is the Eastern Berber language that is spoken in Egypt?
# Matched Sequence: eastern berber language Score: 0.662162162162
#
#
# associate director , white house office of public liaison 0.645833333333
# Question: What country is the official with the title of Associate Director, White House Office of Public Liaison from?
# Matched Sequence: associate director , white house office of public liaison Score: 0.645833333333
#
#
# states 0.5
# Question: What movie from the Untied States was Liam Hemsworth?
# Matched Sequence: states Score: 0.5
#
#
# isolate language 0.596153846154
# Question: What isolate language does Guyana speak?
# Matched Sequence: isolate language Score: 0.596153846154
#
#
# the associate director of white house office of public 0.553846153846
# Question: What was the former occupation of the Associate Director of White House Office of Public Liaison?
# Matched Sequence: the associate director of white house office of public Score: 0.553846153846
#
#
# alien-invasion 0.5
# Question: What alien-invasion themed movie starred Rihanna?
# Matched Sequence: alien-invasion Score: 0.5
#
#
# correspondence of charles darwin , volume 12 0.505952380952
# Question: What other works were done by the author who published editions for "The Correspondence of Charles Darwin, Volume 12"?
# Matched Sequence: correspondence of charles darwin , volume 12 Score: 0.505952380952
#
#
# a good newspaper is a nation talking to itself 0.940298507463
# Question: The person that said "A good newspaper is a nation talking to itself" was influenced by who?
# Matched Sequence: a good newspaper is a nation talking to itself Score: 0.940298507463
#
#
# batlesville 0.571428571429
# Question: What person born in Batlesville was the first leader of the AFL?
# Matched Sequence: batlesville Score: 0.571428571429
#
#
# french minister of the economy , finance and 0.461538461538
# Question: Who is the leader of the government that has the position title French Minister of the Economy, Finance and Industry 2012?
# Matched Sequence: french minister of the economy , finance and Score: 0.461538461538
#
#
# jonas brother 0.4375
# Question: Which Jonas brother ended a celebrity relationship in 2007?
# Matched Sequence: jonas brother Score: 0.4375
#
#
# emomali rahmon 0.403846153846
# Question: What country bordering China appointed Emomali Rahmon to a governmental position?
# Matched Sequence: emomali rahmon Score: 0.403846153846
#
#
# dioncounda traora 0.508474576271
# Question: Which countries does the Niger River flow through, where the location that appointed Dioncounda TraorÃ© to a governmental position?
# Matched Sequence: dioncounda traora Score: 0.508474576271
#
#
# sons and daughters of st 0.427272727273
# Question: What airport is close to Sandals Grande in the country with national anthem Sons and daughters of St. Lucia?
# Matched Sequence: sons and daughters of st Score: 0.427272727273
#
#
# ilinois river 0.4375
# Question: Which state has Jim Edgar as a government member and includes the Ilinois River as a landmark?
# Matched Sequence: ilinois river Score: 0.4375
#
#
# feinstein 0.416666666667
# Question: What is the name of the main train station of the city that Diane Feinstein was appointed for a governmental position?
# Matched Sequence: feinstein Score: 0.416666666667
#
#
# labanese pound 0.714285714286
# Question: What Arabic speaking country that uses Labanese pound for its currency?
# Matched Sequence: labanese pound Score: 0.714285714286
#
#
# plevneliev 0.454545454545
# Question: What country that is part of NATO appointed Rosen Plevneliev to a governmental position?
# Matched Sequence: plevneliev Score: 0.454545454545
#
#
# aires 0.75
# Question: Buenos Aires is the capital of what country bordering Bolivia?
# Matched Sequence: aires Score: 0.75
#
#
# district 0.428571428571
# Question: What NATO countries contain the airport that serves Kleve (district)?
# Matched Sequence: district Score: 0.428571428571
# garfield : 0.6
# Question: What movie stars actress Alyson Stoner and is a prequel to Garfield: A Tail of Two Kitties?
# Matched Sequence: garfield : Score: 0.6
#
#
# that has such people i n't 0.41095890411
# Question: Who said "...O brave new world, That has such people in't!" that influenced Arthur Miller?
# Matched Sequence: that has such people i n't Score: 0.41095890411
#
#
# lawrence 0.454545454545
# Question: Which of the tv shows on which Joey Lawrence played has the largest "tvrage_id"?
# Matched Sequence: lawrence Score: 0.454545454545
#
#
# tortall universe 0.454545454545
# Question: What language do the Navajo people and the fictional Tortall  Universe have in common?
# Matched Sequence: tortall universe Score: 0.454545454545
#
#
# i am not young enough to know everything 0.921739130435
# Question: What influencer of Whitnam's poetry is the person who said, "I am not young enough to know everything"?
# Matched Sequence: i am not young enough to know everything Score: 0.921739130435
#
#
# , the sun 0.40625
# Question: Which type of government, which was practiced in Sparta, Greece, was also featured in "I, the Sun?"?
# Matched Sequence: , the sun Score: 0.40625
#
#
# family adventure 0.526315789474
# Question: Which Harry Potter movies are considered part of the family adventure genre?
# Matched Sequence: family adventure Score: 0.526315789474
#
#
# university 0.533333333333
# Question: What university was attended by the actor from the film "Hang Loose"?
# Matched Sequence: university Score: 0.533333333333
#
#
# polynesian language 0.854545454545
# Question: What language do Chilean people speak that belongs to the Polynesian language family?
# Matched Sequence: polynesian language Score: 0.854545454545
#
#
# finno-ugric language 0.608695652174
# Question: What dialects spoken in Finland belong to the Finno-Ugric language family?
# Matched Sequence: finno-ugric language Score: 0.608695652174
#
#
# the sun also shines on the widked 0.76
# Question: What influencer of William Shakespeare said "The sun also shines on the widked"?
# Matched Sequence: the sun also shines on the widked Score: 0.76
#
#
# azerbaijani as 0.435483870968
# Question: What Arabic-speaking country also has Azerbaijani as a spoken language?
# Matched Sequence: azerbaijani as Score: 0.435483870968
#
#
# theodore schwann 0.421052631579
# Question: What college with the latest founding date did Theodore Schwann attend?
# Matched Sequence: theodore schwann Score: 0.421052631579
#
#
# greek temples 0.45
# Question: Where was the ficitional character Aglaulus, daughter of Cecrops born and the Greek temples built?
# Matched Sequence: greek temples Score: 0.45
#
#
# of the associate director , white house office of public 0.55223880597
# Question: Which candidate for Vice President in 2012 once held the title of the Associate Director, White House Office of Public Liaison?
# Matched Sequence: of the associate director , white house office of public Score: 0.55223880597
#
#
# harry potter film 0.55
# Question: What is the most recent Harry Potter film in the series to be released?
# Matched Sequence: harry potter film Score: 0.55
#
#
# berber language 0.833333333333
# Question: Which country speaks Arabic and has a Berber language as its official language?
# Matched Sequence: berber language Score: 0.833333333333
#
#
# assassinated 0.512820512821
# Question: Who was assassinated and influenced Walt Whitman's poems?
# Matched Sequence: assassinated Score: 0.512820512821
#
#
# transformers : 0.714285714286
# Question: What location is shared by pyramids and the film Transformers: Revenge of the Fallen?
# Matched Sequence: transformers : Score: 0.714285714286
#
#
# harvard advocate 0.446153846154
# Question: Which state is publisher of the periodical journal The Harvard Advocate located in?
# Matched Sequence: harvard advocate Score: 0.446153846154
#
#
# pornographic 0.421052631579
# Question: Miley Cyrus starred in which pornographic cartoons?
# Matched Sequence: pornographic Score: 0.421052631579
#
#
# states senate election in alaska 0.451388888889
# Question: What country held theUnited States Senate election in Alaska, 2008?
# Matched Sequence: states senate election in alaska Score: 0.451388888889
#
#
# karbovanet 0.428571428571
# Question: Who knows what other currencies are used beside the Karbovanet in Ukraine?
# Matched Sequence: karbovanet Score: 0.428571428571
#
#
# united state senate election in 2008 0.479452054795
# Question: Which is the state capital city that held the United State Senate election in 2008, in Montana?
# Matched Sequence: united state senate election in 2008 Score: 0.479452054795
#
#
# anglo portuguese 0.41095890411
# Question: What was the form of government practiced by ancient Greek spartans and the Anglo Portuguese troops?
# Matched Sequence: anglo portuguese Score: 0.41095890411
#
#
# movie 0.5
# Question: What television movie starred Lucy Hale?
# Matched Sequence: movie Score: 0.5
#
#
# governor general of the province of 0.545454545455
# Question: In what country did the Governor General of the Province of Canada reign as political appointer?
# Matched Sequence: governor general of the province of Score: 0.545454545455
#
#
# university 0.533333333333
# Question: What university was attended by the actor from Man-Up!?
# Matched Sequence: university Score: 0.533333333333
#
#
# first thing we do , let 's kill all the lawyer 0.72027972028
# Question: Who is the person who said "First thing we do, let's kill all the lawyer." and influenced Arthur Miller?
# Matched Sequence: first thing we do , let 's kill all the lawyer Score: 0.72027972028
#
#
# paddington 0.5
# Question: What country that borders Bolivia is where Paddington was born?
# Matched Sequence: paddington Score: 0.5
#
#
# lombardi comorehensive cancer 0.408
# Question: Which college that Bill Clinton attended has the Lombardi Comorehensive Cancer Center?
# Matched Sequence: lombardi comorehensive cancer Score: 0.408
#
#
# israeli lire 0.676470588235
# Question: Which continent currently uses the Israeli lire currency?
# Matched Sequence: israeli lire Score: 0.676470588235
#
#
# and field 0.538461538462
# Question: Is the most famous athlete in Kenya a track and field athlete?
# Matched Sequence: and field Score: 0.538461538462
#
#
# greek temples 0.45
# Question: What region is an administrative division in Libya and is where Greek temples were built?
# Matched Sequence: greek temples Score: 0.45
#
#
# greek temples 0.45
# Question: What landmarks was the location in the movie "My life in ruins" and where greek temples were built?
# Matched Sequence: greek temples Score: 0.45
#
#
# alien-invasion 0.5
# Question: What alien-invasion themed movie starred Rihanna?
# Matched Sequence: alien-invasion Score: 0.5
#
#
# power plugs 0.411764705882
# Question: in what  country is it where people speak arabic and compatible power plugs are type f?
# Matched Sequence: power plugs Score: 0.411764705882
#
#
# lichtensein 0.473684210526
# Question: What artist was nominated for the Grammy Award for Best Recording Package and is said to have influenced Roy Lichtensein Artwork?
# Matched Sequence: lichtensein Score: 0.473684210526
#
#
# start test
# rihanna : live in concert tour 0.421052631579
# Question: Where was the main artist featured in the Rihanna: Live in Concert Tour raised?
# Matched Sequence: rihanna : live in concert tour Score: 0.421052631579
#
#
# payton manning 0.411764705882
# Question: What team did Payton Manning's father play for that has a mascot named Viktor the Viking?
# Matched Sequence: payton manning Score: 0.411764705882
#
#
# william j taverner 0.491525423729
# Question: Who founded the school where William J. Taverner is a grad student?
# Matched Sequence: william j taverner Score: 0.491525423729
#
#
# ardulfurataini 0.611111111111
# Question: What is the government type where "Ardulfurataini Estan" is the national anthem?
# Matched Sequence: ardulfurataini Score: 0.611111111111
#
#
# sacatepaquez 0.428571428571
# Question: What currency is used in the country with SacatepÃ©quez Department?
# Matched Sequence: sacatepaquez Score: 0.428571428571
#
#
# bresciani 0.473684210526
# Question: Dean L. Bresciani is part of the organization with what mascot?
# Matched Sequence: bresciani Score: 0.473684210526
#
#
# patria , tu hermosa 0.443298969072
# Question: What currency is used in the country with Nobel Patria, tu hermosa as its national anthem?
# Matched Sequence: patria , tu hermosa Score: 0.443298969072
#
#
# statford northwestern secondary 0.469696969697
# Question: Where did the person who went to Statford Northwestern Secondary school grow up?
# Matched Sequence: statford northwestern secondary Score: 0.469696969697
#
#
# louis-eugene cavaignac 0.428571428571
# Question: Before the Euro, what was the currency where Louis-Eugene Cavaignac was appointed to governmental position?
# Matched Sequence: louis-eugene cavaignac Score: 0.428571428571
#
#
# president kennedy 0.415584415584
# Question: What college did President Kennedy attend that has a sports team Princeton Tigers men's basketball?
# Matched Sequence: president kennedy Score: 0.415584415584
#
#
# iranian rail 0.435897435897
# Question: What form of government is in the country that uses the Iranian Rail and was established in 1979?
# Matched Sequence: iranian rail Score: 0.435897435897
# scott fitzgerald 0.578947368421
# Question: Who inspired Scott Fitzgerald that is the architect who designed The Mount?
# Matched Sequence: scott fitzgerald Score: 0.578947368421
#
#
# football 0.416666666667
# Question: What educational institution with football sports team named Iowa Hawkeyes did Tennessee Williams go to college?
# Matched Sequence: football Score: 0.416666666667
#
#
# german 0.5
# Question: Which German bordering country appointed Georges Pompidou to governmental position?
# Matched Sequence: german Score: 0.5
#
#
# magallenes y la antarctica chilena region 0.438709677419
# Question: What languages are used for verbal communication in the nation where Magallenes y la Antarctica Chilena Region is located?
# Matched Sequence: magallenes y la antarctica chilena region Score: 0.438709677419
#
#
# basketball 0.446808510638
# Question: What educational institution with men's basketball sports team named Purdue Boilermakers did Drew Brees go to college?
# Matched Sequence: basketball Score: 0.446808510638
#
#
# united states senate election of hawaii in 0.425149700599
# Question: What is the national flower of the state that held the United States Senate election of Hawaii in 2010?
# Matched Sequence: united states senate election of hawaii in Score: 0.425149700599
#
#
# i destroy my enemy when i make him my friend 0.801587301587
# Question: What political offices were held by the person who said, "I destroy my enemy when I make him my friend?"?
# Matched Sequence: i destroy my enemy when i make him my friend Score: 0.801587301587
#
#
# anthony carmelo -lrb- whitehouse 0.431034482759
# Question: Where does the subject of the image "Anthony Carmelo (Whitehouse) make their home?
# Matched Sequence: anthony carmelo -lrb- whitehouse Score: 0.431034482759
#
#
# nothing pains some people more than having to think 0.931818181818
# Question: What college did the person that said "Nothing pains some people more than having to think." complete his doctorate education?
# Matched Sequence: nothing pains some people more than having to think Score: 0.931818181818
#
#
# peruviana hairless dog 0.409638554217
# Question: What is the type of goverment in the place where the Peruviana Hairless Dog originated?
# Matched Sequence: peruviana hairless dog Score: 0.409638554217
#
#
# i have always depended on the kindness of strangers 0.939189189189
# Question: Where did the person that stated "I have always depended on the kindness of strangers.", attend university?
# Matched Sequence: i have always depended on the kindness of strangers Score: 0.939189189189
#
#
# german 0.5
# Question: Which German border country has the largest country calling code?
# Matched Sequence: german Score: 0.5
#
#
# forgive your enemies , but never forget their names 0.856164383562
# Question: What is the hometown of the person who said "Forgive your enemies, but never forget their names?"?
# Matched Sequence: forgive your enemies , but never forget their names Score: 0.856164383562
#
#
# jj-thomson2 0.571428571429
# Question: What did the scientist who was the topic of the jj-thomson2 image discover?
# Matched Sequence: jj-thomson2 Score: 0.571428571429
#
#
# montelbaanstoren -lrb- 1512 -rrb- on the oude schans 0.407608695652
# Question: In what nation would you find the topic of the image "The Montelbaanstoren (1512) on the Oude Schans"?
# Matched Sequence: montelbaanstoren -lrb- 1512 -rrb- on the oude schans Score: 0.407608695652
#
#
# forgive your enemies , but never forget their names 0.856164383562
# Question: Who is the brother of the person that said "Forgive your enemies, but never forget their names."?
# Matched Sequence: forgive your enemies , but never forget their names Score: 0.856164383562
#
#
# under secretary of defense for personnel 0.455555555556
# Question: In what subject does the politician who held the position Under Secretary of Defense for Personnel and Readiness hold a degree?
# Matched Sequence: under secretary of defense for personnel Score: 0.455555555556
#
#
# 's first creature , which was light 0.763157894737
# Question: What did the person who said "God's first creature, which was light" do?
# Matched Sequence: 's first creature , which was light Score: 0.763157894737
#
#
# ...
# Matched Sequence: cruella deville Score: 0.423076923077
#
#
# countries 0.5
# Question: What nordic countries are in the Central European Time Zone?
# Matched Sequence: countries Score: 0.5
#
#
# kicker 0.444444444444
# Question: Who is the kicker of the sports franchise that is owned by Arthur Blank?
# Matched Sequence: kicker Score: 0.444444444444
#
#
# cruella deville 0.423076923077
# Question: Who portrayed the character Cruella deVille in the movie featuring a character called Taxi Driver in Black and White Dots?
# Matched Sequence: cruella deville Score: 0.423076923077
#
#
# finno-ugric language 0.608695652174
# Question: What language do Ukrainian people speak that belongs to the Finno-Ugric language family?
# Matched Sequence: finno-ugric language Score: 0.608695652174
#
#
# israeli palestinian 0.458333333333
# Question: Who died on 01/11/2014 and was in the Israeli Palestinian conflict?
# Matched Sequence: israeli palestinian Score: 0.458333333333
#
#
# west germanic language 0.652777777778
# Question: What languages spoken in Germany belong to the West Germanic language family?
# Matched Sequence: west germanic language Score: 0.652777777778
#
#
# languages 0.454545454545
# Question: What languages are used in the country where Ga is a spoken language?
# Matched Sequence: languages Score: 0.454545454545
#
#
# universal 0.545454545455
# Question: What NBC Universal owned tourist attraction can be visited in Orlando, Florida?
# Matched Sequence: universal Score: 0.545454545455
#
#
# emancipation commemoration 0.490384615385
# Question: What city is at once associated with President Barack Obama's current residence and with the Emancipation Commemoration Commission?
# Matched Sequence: emancipation commemoration Score: 0.490384615385
#
#
# theodore schwann 0.421052631579
# Question: What university with the lowest number of undergraduates did Theodore Schwann study at?
# Matched Sequence: theodore schwann Score: 0.421052631579
#
#
# heroes in hell `` fictional 0.451327433628
# Question: What language is spoken in the Czech Republic and is also the language of the "Heroes in Hell" fictional universe?
# Matched Sequence: heroes in hell `` fictional Score: 0.451327433628
#
#
# languages 0.477272727273
# Question: What are the languages spoken in the country where Quechuan language is spoken?
# Matched Sequence: languages Score: 0.477272727273
#
#
# language 0.461538461538
# Question: What is the national language of the country where Talysh is a spoken language?
# Matched Sequence: language Score: 0.461538461538
#
#
# laura ingallls wilder 0.410256410256
# Question: In which administrative division of the country of the United States of America did Laura Ingallls Wilder live?
# Matched Sequence: laura ingallls wilder Score: 0.410256410256
#
#
# championship 0.714285714286
# Question: In what year did the Seattle Seahawks play at the Superbowl where the results of the championship were 43-8?
# Matched Sequence: championship Score: 0.714285714286
#
#
# a taste for simplicity can not endure for long 0.818181818182
# Question: Which artist was an inspirational source for Vincent Van Gogh and once quoted "A taste for simplicity cannot endure for long."?
# Matched Sequence: a taste for simplicity can not endure for long Score: 0.818181818182
#
#
# languages 0.428571428571
# Question: What languages are spoken in the country that speaks Talysh?
# Matched Sequence: languages Score: 0.428571428571
#
#
# languages 0.409090909091
# Question: What languages are also spoken in the country where Romansh is used?
# Matched Sequence: languages Score: 0.409090909091
#
#
# adventures of priscilla , queen of the desert 0.50303030303
# Question: Which Western European country serves as the setting of "The Adventures of Priscilla, Queen of the Desert?"?
# Matched Sequence: adventures of priscilla , queen of the desert Score: 0.50303030303
#
#
# garfield : 0.6
# Question: What movies did Nick Cannon stared in that had a sequel named Garfield: A Tail of Two Kitties?
# Matched Sequence: garfield : Score: 0.6
#
#
# power plugs 0.411764705882
# Question: Which countries speak the Arabic language, and the country has compatible power plugs of Type C?
# Matched Sequence: power plugs Score: 0.411764705882
#
#
# euro 2012 0.461538461538
# Question: What country with a religious organization leadership was the Euro 2012 tournament held in?
# Matched Sequence: euro 2012 Score: 0.461538461538
# indo-european language 0.635135135135
# Question: What language is used in Brazil that belongs to the Indo-European language family?
# Matched Sequence: indo-european language Score: 0.635135135135
#
#
# you have to look at history as an evolution of society 0.942675159236
# Question: Which Canadian prime minister from 1993 said "You have to look at history as an evolution of society?"?
# Matched Sequence: you have to look at history as an evolution of society Score: 0.942675159236
#
#
# the language 0.5
# Question: Which two Chinese dialects that is the language found in the fictional universe Firefly?
# Matched Sequence: the language Score: 0.5
#
#
# language 0.439024390244
# Question: What is another language that is also spoken in the same area that Romansh is spoken?
# Matched Sequence: language Score: 0.439024390244
#
#
# regret to 0.409090909091
# Question: In what country is the Mekong River located and is also the subject of the movie Regret to Reform?
# Matched Sequence: regret to Score: 0.409090909091
#
#
# kingdom of 0.477272727273
# Question: What is the political system that was shared by Spain and the Kingdom of Prussia?
# Matched Sequence: kingdom of Score: 0.477272727273
#
#
# attorney general 0.426470588235
# Question: Who has been the Attorney General of the location with an official symbol called Populus?
# Matched Sequence: attorney general Score: 0.426470588235
#
#
# minister of 0.533333333333
# Question: Where is Shoreditch located, that has the position title the Minister of Ford?
# Matched Sequence: minister of Score: 0.533333333333
#
#
# aguirre , the wrath of 0.431818181818
# Question: Which Spanish speaking country is the setting of the movie Aguirre, the Wrath of God?
# Matched Sequence: aguirre , the wrath of Score: 0.431818181818
#
#
# prime minister of % 0.413793103448
# Question: Who is the current Prime Minister of the governmental jurisdiction where the government includes the position of Prime Minister of Ethiopia?
# Matched Sequence: prime minister of % Score: 0.413793103448
#
#
# language 0.409090909091
# Question: what language is used in the place where Quechuan languages are spoken?
# Matched Sequence: language Score: 0.409090909091
#
#
# montesquie 0.7
# Question: To which member of the Second Continental Congress was Baron de Montesquie a great influence?
# Matched Sequence: montesquie Score: 0.7
#
#
# euro 2012 0.461538461538
# Question: What location was home to the Euro 2012 Tournament?
# Matched Sequence: euro 2012 Score: 0.461538461538
#
#
# catholic 0.5
# Question: What bible with the parable genre does the Catholic Church follow?
# Matched Sequence: catholic Score: 0.5
#
#
# iberian romance language 0.658227848101
# Question: What type of language is spoken in Peru and belongs to the Iberian Romance language family?
# Matched Sequence: iberian romance language Score: 0.658227848101
#
#
# ramdev 0.428571428571
# Question: Which religion practiced in Russia has a deity named Ramdev Pir?
# Matched Sequence: ramdev Score: 0.428571428571
#
#
# minister 0.5
# Question: Who is the Prime Minister of Japan who was appointed Minister of Finance?
# Matched Sequence: minister Score: 0.5
#
#
# fictional universe of `` heroes in hell 0.563492063492
# Question: Which language is spoken in Denmark and the fictional universe of "Heroes in Hell"?
# Matched Sequence: fictional universe of `` heroes in hell Score: 0.563492063492
#
#
# power plugs 0.411764705882
# Question: What country bordering reece that has compatible power plugs of type C?
# Matched Sequence: power plugs Score: 0.411764705882
#
#
# championship 0.457627118644
# Question: What was the year in which the ravens won the super bowl and the championship event was $target?
# Matched Sequence: championship Score: 0.457627118644
#
#
# thailand national under-23 0.592920353982
# Question: Venue near Bangkok where the Thailand National under-23 sport's team play.?
# Matched Sequence: thailand national under-23 Score: 0.592920353982
#
#
# : for the kingdom of heaven is at hand 0.84126984127
# Question: What God do Catholics believe in who said, "Repent: for the kingdom of heaven is at hand."?
# Matched Sequence: : for the kingdom of heaven is at hand Score: 0.84126984127
#
#
# euro 2012 0.461538461538
# Question: Where was the author of Without End born that is also where the Euro 2012 Tournament was held?
# Matched Sequence: euro 2012 Score: 0.461538461538
#
#
# mathamatician 0.47619047619
# Question: What mathamatician discovered Neptune?
# Matched Sequence: mathamatician Score: 0.47619047619
#
#
# movies 0.428571428571
# Question: Which movies made for television did Diana Ross play in?
# Matched Sequence: movies Score: 0.428571428571
#
#
# german 0.5
# Question: What film was directed by Ron Howard and has German ties?
# Matched Sequence: german Score: 0.5
#
#
# victoria 0.416666666667
# Question: What country border Lake Victoria that has the capital Dodoma?
# Matched Sequence: victoria Score: 0.416666666667
#
#
# government of new zealand 0.432432432432
# Question: Where does UK import from that appointed the Return Government of New Zealand to a governmental position?
# Matched Sequence: government of new zealand Score: 0.432432432432
#
#
# vincent c 0.416666666667
# Question: Where is Howard University located, that appointed Vincent C. Gray, to a governmental position?
# Matched Sequence: vincent c Score: 0.416666666667
#
#
# euro 2012 0.461538461538
# Question: Where with religious leader Pean was the Euro 2012 Tournament?
# Matched Sequence: euro 2012 Score: 0.461538461538
#
#
# district 0.428571428571
# Question: What country beside France contains an airport that serves Kleve (district)?
# Matched Sequence: district Score: 0.428571428571
#
#
# robert f kennedy 0.444444444444
# Question: What school with The Cavalier Daily newspaper did Robert F. Kennedy go to?
# Matched Sequence: robert f kennedy Score: 0.444444444444
#
#
# herzegovina dinar 0.506493506494
# Question: On what countinent is the Bosnia and Herzegovina dinar accepted as currency?
# Matched Sequence: herzegovina dinar Score: 0.506493506494
#
#
# catholic 0.5
# Question: What practicing Catholic was Prime Minister of Spain in 2011?
# Matched Sequence: catholic Score: 0.5
#
#
# nordic country 0.625
# Question: Of the countries that border Germany, which one is an Nordic country as well?
# Matched Sequence: nordic country Score: 0.625
#
#
# baptist 0.571428571429
# Question: What Baptist was a state senator in Louisiana?
# Matched Sequence: baptist Score: 0.571428571429
#
#
# ley de artitraje 0.555555555556
# Question: What Latin America country does the work Ley de Artitraje originated?
# Matched Sequence: ley de artitraje Score: 0.555555555556
#
#
# brooklyn dodgers 1947 0.40625
# Question: In which year did the Yankees win the championship that was also the Brooklyn Dodgers 1947 season?
# Matched Sequence: brooklyn dodgers 1947 Score: 0.40625
#
#
# they shall be comforted 0.4375
# Question: Whence was the person who said "Blessed are they that mourn: for they shall be comforted" after he was crucified?
# Matched Sequence: they shall be comforted Score: 0.4375
#
#
# susqehannah case 0.5
# Question: In which state does the Connecticut river flow through where "The Susqehannah Case" was written?
# Matched Sequence: susqehannah case Score: 0.5
#
#
# united states senate election in 0.454545454545
# Question: In which time zone is Hawaii, that held the United States Senate election in 2010 ?
# Matched Sequence: united states senate election in Score: 0.454545454545
#
#
# what about harvard 0.566666666667
# Question: Where did Robert Frost, who wrote "What about Harvard", go to school?
# Matched Sequence: what about harvard Score: 0.566666666667
#
#
# other languages 0.444444444444
# Question: In the country where the Afshar language is used, what other languages are spoken?
# Matched Sequence: other languages Score: 0.444444444444
#
#
# catholic 0.5
# Question: Which memebers of John F Kennedy's family were followers of the Catholic religion?
# Matched Sequence: catholic Score: 0.5
#
#
# aragonese 0.461538461538
# Question: Which language group begat the Danish language and is part of the Aragonese family?
# Matched Sequence: aragonese Score: 0.461538461538
#
#
# israeli palestinian 0.458333333333
# Question: What politician held their governmental position since 1972-01-16 and was in the Israeli Palestinian Conflict?
# Matched Sequence: israeli palestinian Score: 0.458333333333
#
#
# minister 0.5
# Question: Which 2011 Prime Minister of Japan ended his/her tenure after September 2, 2011?
# Matched Sequence: minister Score: 0.5
#
#
# languages 0.409090909091
# Question: What other languages are spoken in places with Romansh speakers?
# Matched Sequence: languages Score: 0.409090909091
#
#
# northern mockingbord 0.465753424658
# Question: Which state is port St Lucie located and has the Northern Mockingbord as its symbol?
# Matched Sequence: northern mockingbord Score: 0.465753424658
#
#
# chancellorsville battle 0.578313253012
# Question: What Mid-Atlantic State did Chancellorsville Battle take place?
# Matched Sequence: chancellorsville battle Score: 0.578313253012
#
#
# northwest , washington 0.425531914894
# Question: In which place did President Barack Obama live, which is located in Northwest, Washington, D.C.?
# Matched Sequence: northwest , washington Score: 0.425531914894
#
#
# euro 2012 0.461538461538
# Question: Which city is the birthplace of Adam Zagajewski and also hosted the Euro 2012 tournament?
# Matched Sequence: euro 2012 Score: 0.461538461538
#
#
# cruella deville 0.423076923077
# Question: who played Cruella Deville in the movie that Delphine de Turckheim starred in?
# Matched Sequence: cruella deville Score: 0.423076923077
#
#
# cruella deville 0.423076923077
# Question: What actress portrayed Cruella Deville in the same movie as Karen Kennedy?
# Matched Sequence: cruella deville Score: 0.423076923077
#
#
# presidency 0.5
# Question: What war was the Mexican Revolution part of? What war happened under the presidency of Woodrow Wilson?
# Matched Sequence: presidency Score: 0.5
#
#
# israeli palestinian 0.458333333333
# Question: Who was the 'King' during the Israeli Palestinian Conflict?
# Matched Sequence: israeli palestinian Score: 0.458333333333
#
#
# kevorkian 0.461538461538
# Question: What was the subject of the film Vincenzo Proietti and the thing that made Dr. Kevorkian famous?"?
# Matched Sequence: kevorkian Score: 0.461538461538
#
#
# flickerman 0.4375
# Question: Find a movie that sstars Sandino Moya and has a character name Ceasar Flickerman, who played ceasar?
# Matched Sequence: flickerman Score: 0.4375
#
#
# balkan 0.5
# Question: Where will you find adaptable Type F power plugs in the Balkan Peninsula?
# Matched Sequence: balkan Score: 0.5
#
#
# robert khardashian 0.55
# Question: Which college with 16500 postgraduates did Robert Khardashian attend?
# Matched Sequence: robert khardashian Score: 0.55
#
#
# phillipines 0.5
# Question: Which administrative division in the Phillipines containes Puerto Galera?
# Matched Sequence: phillipines Score: 0.5
#
#
# coat of arms of 0.417721518987
# Question: Where were the Seneca Indians located and what country's coat of arms is the Coat of Arms of St. Catherine?
# Matched Sequence: coat of arms of Score: 0.417721518987
#
#
# michael murray 0.482142857143
# Question: What Christina Ricci movie does Michael Murray play in?
# Matched Sequence: michael murray Score: 0.482142857143
#
#
# montesquie 0.7
# Question: Which Democratic-Republican Party Members did Baron De Montesquie influence?
# Matched Sequence: montesquie Score: 0.7
#
#
# philippine 0.888888888889
# Question: Which elected president of the Philippines was part of the Philippine Independent Church?
# Matched Sequence: philippine Score: 0.888888888889
#
#
# israeli palestinian 0.458333333333
# Question: Who was appointed by Ronald Reagan during the Israeli Palestinian conflict?
# Matched Sequence: israeli palestinian Score: 0.458333333333
#
#
# university 0.4375
# Question: The University of Auburn and the county Lee County, are part of what country?
# Matched Sequence: university Score: 0.4375
